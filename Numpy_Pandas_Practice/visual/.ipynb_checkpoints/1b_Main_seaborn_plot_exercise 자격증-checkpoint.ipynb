# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %matplotlib inline

np.random.seed(0) 
x = np.random.randn(100)

# %%
sns.rugplot(x);

# %%
 sns.kdeplot(x);

# %%
sns.distplot(x, kde=True, rug=True);

# %%
import seaborn as sns
tips = sns.load_dataset("tips") 
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips = sns.load_dataset("tips") 
sns.jointplot(x="total_bill", y="tip", data=tips);

# %%
iris = sns.load_dataset("iris") 
sns.jointplot("sepal_width", "petal_length", data=iris, kind="kde", space=0, color="g")

# %%
sns.regplot(x="total_bill", y="tip", data=tips);

residplot(residual)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-04f2b8384a86> in <module>
#       1 sns.regplot(x="total_bill", y="tip", data=tips);
# ----> 2 residplot(residual)
#
# NameError: name 'residplot' is not defined

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips);

# %%
sns.lmplot(x="total_bill", y="tip", col="smoker", data=tips);

# %% [markdown]
# # barplot

# %%
sns.barplot(x="day", y="total_bill",hue='sex' , data=tips);
countplot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-5880b0d046f1> in <module>
#       1 sns.barplot(x="day", y="total_bill",hue='sex' , data=tips);
# ----> 2 countplot
#
# NameError: name 'countplot' is not defined

# %%
titanic = sns.load_dataset("titanic") 
sns.countplot(x="class", hue="who", data=titanic); 
boxplotpointplot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-c14776242008> in <module>
#       1 titanic = sns.load_dataset("titanic")
#       2 sns.countplot(x="class", hue="who", data=titanic);
# ----> 3 boxplotpointplot
#
# NameError: name 'boxplotpointplot' is not defined

# %%
sns.boxplot(x="day", y="total_bill", hue="smoker", data=tips);

# %%
 sns.pointplot(x="time", y="total_bill", hue="smoker", data=tips, dodge=True);

# %%
 sns.violinplot(x="day", y="total_bill", hue="smoker", data=tips, palette="muted");

# %%
 sns.violinplot(x="day", y="total_bill", hue="sex", data=tips, palette="Set2", split=True, scale="count", inner="quartile");

# %%
 sns.stripplot(x="day", y="total_bill", hue="smoker", 
               data=tips, jitter=True, 
               palette="Set2", split=True);
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\categorical.py:2775: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(x="tip", y="day", data=tips, whis=np.inf)
sns.stripplot(x="tip", y="day", data=tips, jitter=True, color=".3");

# %%
 sns.swarmplot(x="day", y="total_bill", hue="sex", data=tips);

# %%
sns.violinplot(x="day", y="total_bill", data=tips, inner=None) 
sns.swarmplot(x="day", y="total_bill", data=tips, color="white", edgecolor="gray");

# %% [markdown]
# # matplotlib imshow .

# %%
flights = sns.load_dataset("flights") 
flights = flights.pivot("month", "year", "passengers") 
sns.heatmap(flights, annot=True, fmt="d");
