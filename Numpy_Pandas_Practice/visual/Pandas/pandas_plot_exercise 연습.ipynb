# %% [markdown]
# # pandas plot exersise 내가 함

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = (15,5) 
plt.rcParams['font.size'] = 14

# %%
drink_cols = ['country', 'beer', 'spirit', 'wine', 'liters', 'continent'] 
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv' 
drinks = pd.read_csv(url, header=0, names=drink_cols, na_filter=False)

# %%
drinks.describe()
# Out:
#              beer      spirit        wine      liters
# count  193.000000  193.000000  193.000000  193.000000
# mean   106.160622   80.994819   49.450777    4.717098
# std    101.143103   88.284312   79.697598    3.773298
# min      0.000000    0.000000    0.000000    0.000000
# 25%     20.000000    4.000000    1.000000    1.300000
# 50%     76.000000   56.000000    8.000000    4.200000
# 75%    188.000000  128.000000   59.000000    7.200000
# max    376.000000  438.000000  370.000000   14.400000

# %%
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
# country      193 non-null object
# beer         193 non-null int64
# spirit       193 non-null int64
# wine         193 non-null int64
# liters       193 non-null float64
# continent    193 non-null object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.1+ KB

# %%
drinks.head()
# Out:
#        country  beer  spirit  wine  liters continent
# 0  Afghanistan     0       0     0     0.0        AS
# 1      Albania    89     132    54     4.9        EU
# 2      Algeria    25       0    14     0.7        AF
# 3      Andorra   245     138   312    12.4        EU
# 4       Angola   217      57    45     5.9        AF

# %%
drinks1 = drinks.copy() 
drinks1.set_index(drinks['country'], inplace =True) 
del drinks1['country'] 
del drinks1.index.name 
drinks1.head()
# Out:
#              beer  spirit  wine  liters continent
# Afghanistan     0       0     0     0.0        AS
# Albania        89     132    54     4.9        EU
# Algeria        25       0    14     0.7        AF
# Andorra       245     138   312    12.4        EU
# Angola        217      57    45     5.9        AF

# %%
drinks['wine'].plot()

# %%
drinks1['beer'][:10].plot(kind='bar')

# %%
drinks[['beer','wine']].plot()

# %%
drinks.plot(kind='scatter', x='beer', y='wine')

# %%
drinks.plot(kind='scatter', x='beer', y='wine', alpha=0.2)

# %%
drinks.plot(kind='scatter', x='beer', y='wine', c='spirit', colormap='Blues')

# %%
pd.plotting.scatter_matrix(drinks)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000015DAAD188D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015DAAD415C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015DAAD689E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015DAB180F60>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015DAB1B2518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015DAB1D7A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015DAB20D048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015DAB2325F8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015DAB232630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015DAB28C0F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015DAB2B3668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015DAB2DABE0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015DAC41C198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015DAC442710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015DAC469C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015DAC49F240>]],
#       dtype=object)

# %%
pd.plotting.scatter_matrix(drinks[['beer', 'spirit', 'wine']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000015DAC4F5B70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015DAC7FA518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015DAC81D940>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015DAC634EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015DAC665470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015DAC68C9E8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015DAC6B4F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015DAC6E7518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015DAC6E7550>]],
#       dtype=object)

# %%
pd.plotting.scatter_matrix(drinks[['beer', 'spirit', 'wine']], figsize=(5, 4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000015DAAC31A20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015DACBA7278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015DACBCE7F0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015DACA35D68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015DACA66320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015DACA8D898>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015DACAB6E10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015DACAE83C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015DACAE8400>]],
#       dtype=object)

# %%
drinks.head(3)
# Out:
#        country  beer  spirit  wine  liters continent
# 0  Afghanistan     0       0     0     0.0        AS
# 1      Albania    89     132    54     4.9        EU
# 2      Algeria    25       0    14     0.7        AF

# %%
drinks.continent.value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# NA    23
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
drinks.continent.value_counts().plot(kind='barh')

# %%
drinks.groupby('continent').mean()
# Out:
#                  beer      spirit        wine    liters
# continent
# AF          61.471698   16.339623   16.264151  3.007547
# AS          37.045455   60.840909    9.068182  2.170455
# EU         193.777778  132.555556  142.222222  8.617778
# NA         145.434783  165.739130   24.521739  5.995652
# OC          89.687500   58.437500   35.625000  3.381250
# SA         175.083333  114.750000   62.416667  6.308333

# %%
drinks.groupby('continent').mean().plot(kind='bar')

# %%
drinks.groupby('continent').mean().plot(kind='bar', stacked=True)

# %%
drinks.groupby('continent').mean().drop('liters', axis=1).plot(kind='bar')

# %%
drinks.groupby('continent').mean().drop('liters', axis=1).plot(kind='bar', stacked=True)

# %%
drinks.spirit.sort_values().head()
# Out:
# 0      0
# 27     0
# 128    0
# 118    0
# 111    0
# Name: spirit, dtype: int64

# %%
drinks.head(3)
# Out:
#        country  beer  spirit  wine  liters continent
# 0  Afghanistan     0       0     0     0.0        AS
# 1      Albania    89     132    54     4.9        EU
# 2      Algeria    25       0    14     0.7        AF

# %%
drink_country = drinks[['beer', 'wine']].sum(axis=1)
drink_country.index=drinks.country
drink_country10 = drink_country.sort_values(ascending=False)[:10] 
drink_country10.plot(kind='bar')

# %%
drinks.sum(axis=1).plot(kind='bar')

# %%
drinks[['beer','spirit','wine','liters']].sum(axis=0).plot(kind='bar')

# %%
drinks.head()
# Out:
#        country  beer  spirit  wine  liters continent
# 0  Afghanistan     0       0     0     0.0        AS
# 1      Albania    89     132    54     4.9        EU
# 2      Algeria    25       0    14     0.7        AF
# 3      Andorra   245     138   312    12.4        EU
# 4       Angola   217      57    45     5.9        AF

# %%
drinks.plot(kind='box')

# %%
drinks.spirit.plot(kind='box')

# %%
drinks.boxplot(column='beer', by='continent')

# %%
drinks.groupby('continent').mean().T
# Out:
# continent         AF         AS          EU          NA        OC          SA
# beer       61.471698  37.045455  193.777778  145.434783  89.68750  175.083333
# spirit     16.339623  60.840909  132.555556  165.739130  58.43750  114.750000
# wine       16.264151   9.068182  142.222222   24.521739  35.62500   62.416667
# liters      3.007547   2.170455    8.617778    5.995652   3.38125    6.308333

# %%
drinks.groupby('continent').mean().T.plot(kind='box')

# %%
drinks.boxplot(by='continent')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000015DADFCA748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015DAE39F630>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000015DAE3C7898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000015DAE3F2B70>]],
#       dtype=object)

# %%
drinks.beer.plot(kind='hist', bins=20, title='Histogram of Beer Servings')

# %%
plt.xlabel('Beer Servings')
# Out:
# Text(0.5, 0, 'Beer Servings')

# %%
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.savefig('beer_histogram_original.png')
